# %%
import pandas as pd
# Out:
# Running cells with 'ProjectVenv' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Code/Basketball  data SCRAPING/App/data/ProjectVenv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
titanic_data = pd.read_csv("C:/Users/Admin/Documents/titanic_data.csv")

# %%
titanic_data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 732          733         0       2
# 186          187         1       3
# 425          426         0       3
# 880          881         1       2
# 788          789         1       3
# 313          314         0       3
# 14            15         0       3
# 315          316         1       3
# 556          557         1       1
# 722          723         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 732                               Knight, Mr. Robert J    male   NaN      0
# 186    O'Brien, Mrs. Thomas (Johanna "Hannah" Godfrey)  female   NaN      1
# 425                             Wiseman, Mr. Phillippe    male   NaN      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 788                         Dean, Master. Bertram Vere    male   1.0      1
# 313                             Hendekovic, Mr. Ignjac    male  28.0      0
# ...
